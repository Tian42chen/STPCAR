# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from preprocess import loadDepthMap, showDepthMap, depth2pcd, save_depth_as_pcd, load_pcd, save_all_depth_as_pcd

# %%
import open3d as o3d

# 将NumPy数组转换为Open3D格式
pcd = o3d.geometry.PointCloud()
pcd.points = o3d.utility.Vector3dVector(depth2pcd(depthmap[5]))

# 可视化点云
o3d.visualization.draw_geometries([pcd])
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
save_all_depth_as_pcd()
# Out:
# 2023-07-04 22:36:04,858 - INFO - Starting to process all depth images
# 2023-07-04 22:36:04,860 - INFO - Converting depth map to point cloud for file a01_s01_e01
# 2023-07-04 22:36:06,475 - INFO - Converting depth map to point cloud for file a01_s01_e02
# 2023-07-04 22:36:07,913 - INFO - Converting depth map to point cloud for file a01_s01_e03
# 2023-07-04 22:36:09,559 - INFO - Converting depth map to point cloud for file a01_s02_e01
# 2023-07-04 22:36:11,094 - INFO - Converting depth map to point cloud for file a01_s02_e02
# 2023-07-04 22:36:11,876 - INFO - Converting depth map to point cloud for file a01_s02_e03
# 2023-07-04 22:36:13,094 - INFO - Converting depth map to point cloud for file a01_s03_e01
# 2023-07-04 22:36:14,256 - INFO - Converting depth map to point cloud for file a01_s03_e02
# 2023-07-04 22:36:15,139 - INFO - Converting depth map to point cloud for file a01_s03_e03
# 2023-07-04 22:36:16,008 - INFO - Converting depth map to point cloud for file a01_s05_e01
# ...

# %%
pcd=load_pcd('a01_s01_e01')
print(len(pcd))
print(pcd[0].shape)
# Out:
# 54
# (7262, 3)
